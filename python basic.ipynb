# %%
#  Math and Number Functions
a = -5
b = 3.456

print("abs(a):", abs(a))              # Absolute value
print("round(b):", round(b))          # Rounds to nearest int
print("pow(2, 3):", pow(2, 3))        # 2^3 = 8
print("max(1, 5, 3):", max(1, 5, 3))  # Maximum value
print("min(1, 5, 3):", min(1, 5, 3))  # Minimum value
print("sum([1, 2, 3]):", sum([1, 2, 3]))  # Sum of all items
print("divmod(10, 3):", divmod(10, 3))   # Returns (quotient, remainder)
print("bin(10):", bin(10))            # Binary representation
print("hex(10):", hex(10))            # Hexadecimal
print("oct(10):", oct(10))            # Octal

print("-" )

#  Type Conversion Functions
print("int('5'):", int("5"))
print("float('3.14'):", float("3.14"))
print("str(100):", str(100))
print("bool(1):", bool(1))
print("list('abc'):", list("abc"))
print("tuple([1, 2]):", tuple([1, 2]))
print("set([1, 2, 2]):", set([1, 2, 2]))
print("dict([(1, 'a'), (2, 'b')]):", dict([(1, 'a'), (2, 'b')]))
print("complex(2, 3):", complex(2, 3))
          

print("-" )

#  Type Checking
x = 5
print("type(x):", type(x))


print("-" * 30)

#  Data Structure Helpers
nums = [9, 2, 3, 4]
print("len(nums):", len(nums))
print("sorted(nums):", sorted(nums))

print("-" * 30)

#  Input and Output

user_input = input("Enter something: ")
print("You entered:", user_input)
# Out:
# abs(a): 5
# round(b): 3
# pow(2, 3): 8
# max(1, 5, 3): 5
# min(1, 5, 3): 1
# sum([1, 2, 3]): 6
# divmod(10, 3): (3, 1)
# bin(10): 0b1010
# hex(10): 0xa
# oct(10): 0o12
# -
# int('5'): 5
# float('3.14'): 3.14
# str(100): 100
# bool(1): True
# list('abc'): ['a', 'b', 'c']
# tuple([1, 2]): (1, 2)
# set([1, 2, 2]): {1, 2}
# dict([(1, 'a'), (2, 'b')]): {1: 'a', 2: 'b'}
# complex(2, 3): (2+3j)
# -
# type(x): <class 'int'>
# ------------------------------
# len(nums): 4
# sorted(nums): [2, 3, 4, 9]
# ------------------------------
# Enter something: 3
# You entered: 3

# %%
def place(name):
    return "to "+ name
print(place("Bangalore"))
# Out:
# to Bangalore

# %%
pip install qrcode
# Out:
# Collecting qrcodeNote: you may need to restart the kernel to use updated packages.
#
#   Obtaining dependency information for qrcode from https://files.pythonhosted.org/packages/29/e6/273de1f5cda537b00bc2947082be747f1d76358db8b945f3a60837bcd0f6/qrcode-8.1-py3-none-any.whl.metadata
#   Downloading qrcode-8.1-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: colorama in c:\users\namratha kadam\anaconda3\lib\site-packages (from qrcode) (0.4.6)
# Downloading qrcode-8.1-py3-none-any.whl (45 kB)
#    ---------------------------------------- 0.0/45.7 kB ? eta -:--:--
#    -------------------------- ------------- 30.7/45.7 kB ? eta -:--:--
#    ---------------------------------------- 45.7/45.7 kB 572.1 kB/s eta 0:00:00
# Installing collected packages: qrcode
# Successfully installed qrcode-8.1

# %%
import qrcode
def generate_qr(link):
    qr = qrcode.make(link)
    qr.save("instragram_qr.png")
    print("QR code saves as instagram_qr.png ")

# %%
generate_qr("https://www.instagram.com/__namratha_30?igsh=dzUzamcyMWRuc3Rr")
# Out:
# QR code saves as instagram_qr.png

# %%
def add(x,y):
    return x+y
add(76,9)
# Out:
# 85
